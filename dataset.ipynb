# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %%
import pandas as pd

# try reading as Excel (because file still corrupted)
df = pd.read_excel(r"data.csv")

# save proper CSV
df.to_csv("clean_data.csv", index=False)

print("Done")
# Out:
# Done

# %%
import pandas as pd

df = pd.read_excel("data.csv")
df.to_csv("clean_data.csv", index=False)

print("Done")
# Out:
# Done
